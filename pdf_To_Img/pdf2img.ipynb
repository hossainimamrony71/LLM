# %%
# !pip install pdf2image
# !apt install poppler-utils
# !apt install libpoppler-cpp-dev

# %%
from pdf2image import convert_from_path


pdf_path = '/content/abc.pdf'


output_folder = '/content/output_images'
# !mkdir -p {output_folder}


images = convert_from_path(pdf_path)


for i, image in enumerate(images):
  image.save(f'{output_folder}/page_{i+1}.jpg', 'JPEG')

print(f'PDF converted to images and saved to "{output_folder}" folder.')
# Out:
# PDF converted to images and saved to "/content/output_images" folder.

# %%
import shutil

# Assuming your image folder is named 'output_images'
shutil.make_archive('output_images', 'zip', 'output_images')
# Out:
# '/content/output_images.zip'

# %%
from google.colab import files

files.download('output_images.zip')
